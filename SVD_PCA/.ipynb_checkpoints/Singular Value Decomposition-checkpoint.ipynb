# %%
from warnings import filterwarnings 
filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import scipy.stats
from scipy.linalg import svd
#from numpy.linalg import svd

pd.set_option('display.width', 100)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("../data/boston_house_prices.csv")
describe_df = df.describe()
descripe_std_df = describe_df.loc["std"].sort_values(ascending=False)
reorg_df = df[descripe_std_df.index]

print(reorg_df.head())
print("\n")

U, S, Vt = svd(reorg_df, full_matrices=False)
num_sv = np.arange(1, S.size+1)

cum_var_explained = [np.sum(S[0:n]) / np.sum(S) for n in num_sv]
print("cum_var_explained")
print(cum_var_explained)
print("\n")

# sdiag = np.diag(S)
sdiag = [np.sum(S[n]) for n in num_sv-1]
print("sdiag")
print(sdiag)
print("\n")
# Out:
#    TAX       B   AGE    ZN  MEDV  RAD     CRIM  LSTAT  INDUS  PTRATIO     DIS     RM  CHAS    NOX
# 0  296  396.90  65.2  18.0  24.0    1  0.00632   4.98   2.31     15.3  4.0900  6.575     0  0.538
# 1  242  396.90  78.9   0.0  21.6    2  0.02731   9.14   7.07     17.8  4.9671  6.421     0  0.469
# 2  242  392.83  61.1   0.0  34.7    2  0.02729   4.03   7.07     17.8  4.9671  7.185     0  0.469
# 3  222  394.63  45.8   0.0  33.4    3  0.03237   2.94   2.18     18.7  6.0622  6.998     0  0.458
# 4  222  396.90  54.2   0.0  36.2    3  0.06905   5.33   2.18     18.7  6.0622  7.147     0  0.458
#
#
# cum_var_explained
# [0.7062339873047019, 0.8997021562553588, 0.9359709644891813, 0.9587708171957511, 0.9703590810693373, 0.9789707854655364, 0.9848671669914306, 0.9899358290071607, 0.9941031099584509, 0.9975022157382795, 0.9988813604342374, 0.9996105430443472, 0.9999170299995133, 1.0]
#
#
# sdiag
# [12594.313684393754, 3450.129633393868, 646.7838649328634, 406.5911611538258, 206.65421504063775, 153.57304869584027, 105.15053066673973, 90.3897582583126, 74.31537486867487, 60.61646027682203, 24.594371312191374, 13.00355787176805, 5.465600527481135, 1.4796090691016957]

# %%
fig = plt.figure(figsize=(5.0,2.5))
ax = fig.add_subplot(111)
plt.plot(sdiag,
         color='#2171b5',
         label='variance')

plt.legend(loc='center right', scatterpoints=1, fontsize=8)
ax.set_xlabel('Number of singular values used')

plt.grid(alpha=0.5, zorder=1)
plt.tight_layout()

# %%
fig = plt.figure(figsize=(5.0,2.5))
ax = fig.add_subplot(111)

plt.plot(num_sv,
         cum_var_explained,
         color='#2171b5',
         label='sum of variances')


plt.legend(loc='center right', scatterpoints=1, fontsize=8)

ax.set_xticks(np.arange(0, S.size-1, 2))

ax.set_ylim(0.4, 1.1)
ax.set_xlabel('Number of singular values used')
# ax.set_ylabel('Sum of variances in data')

plt.grid(alpha=0.5, zorder=1)
plt.tight_layout()
